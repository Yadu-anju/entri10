# %% [markdown]
# <a href="https://colab.research.google.com/github/Yadu-anju/entri10/blob/main/module3end.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("/content/customer_behavior.csv")
df.head(5001)
# Out:
#       CustomerID  Gender Region  PurchaseAmount ProductCategory Churn  \
# 0           1001    Male  South          256.07         Fashion    No
# 1           1002  Female  South             NaN     Electronics   Yes
# 2           1003  Female   West         1194.41         Fashion    No
# 3           1004  Female  South          413.06         Grocery    No
# 4           1005    Male   West         1556.32         Fashion   Yes
# ...          ...     ...    ...             ...             ...   ...
# 4995        5996  Female   West         1497.00     Electronics   Yes
# 4996        5997    Male   West          978.87         Fashion   Yes
# 4997        5998    Male   West          906.93         Fashion    No
# 4998        5999  Female  South          375.67         Fashion    No
# 4999        6000  Female  North         1392.74         Grocery   Yes
#
#      CampaignGroup
# 0                A
# 1                B
# 2                A
# 3                A
# 4                A
# ...

# %% [markdown]
# Average,Median,Mode of "purchase amount

# %%
num_df=df[["PurchaseAmount"]]
num_df.head(5001)
# Out:
#       PurchaseAmount
# 0             256.07
# 1                NaN
# 2            1194.41
# 3             413.06
# 4            1556.32
# ...              ...
# 4995         1497.00
# 4996          978.87
# 4997          906.93
# 4998          375.67
# 4999         1392.74
#
# [5000 rows x 1 columns]

# %%
mean_val=num_df.mean()
mean_val
# Out:
# PurchaseAmount    1003.95067
# dtype: float64

# %%
median_val=num_df.median()
median_val
# Out:
# PurchaseAmount    998.08
# dtype: float64

# %%
mode_val=num_df.mode().iloc[0]
mode_val
# Out:
# PurchaseAmount    0.0
# Name: 0, dtype: float64

# %% [markdown]
# Finding outlayer using scatterplot

# %%
sns.scatterplot(x="PurchaseAmount",y="CustomerID",data=df)
plt.show()

# %% [markdown]
# By seeing the figure, only 5 purchasing amount are surpassing the amount 2500

# %% [markdown]
# Skewness and Kurtosis

# %%
skew_vals=num_df.skew()
skew_vals
# Out:
# PurchaseAmount    0.106092
# dtype: float64

# %% [markdown]
# since the skew value is +ve,Long tale will be on the right side and score is low.

# %%
kurtosis_val=num_df.kurtosis()
kurtosis_val
# Out:
# PurchaseAmount   -0.261511
# dtype: float64

# %% [markdown]
# Since the amout is less than 3,it is Platykurtic

# %% [markdown]
# Difference in spending of Male and Female

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Gender",data=df,hue="Gender")
plt.show()

# %% [markdown]
# Fig shows there is no significant difference in spending

# %%
Relationship between ProductCategory and Customer churn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/customer_behavior.csv")
df.head(5001)
sns.scatterplot(x="ProductCategory",y="Churn",data=df,hue="Churn")
plt.show()

# %% [markdown]
# There is no relationship between Product category and customer churn

# %% [markdown]
# Varying of Purchasing amount

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/customer_behavior.csv")
df.head(5001)
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# Performance of A or B is better

# %%
import pandas as pd
df=pd.read_csv("/content/customer_behavior.csv")
df.head(5001)
group=df.groupby('CampaignGroup')
sum_CampaignGroup=group.sum()
sum_CampaignGroup
# Out:
#                CustomerID                                             Gender  \
# CampaignGroup
# A                 8511748  MaleFemaleFemaleMaleMaleMaleFemaleFemaleFemale...
# B                 8330596  FemaleFemaleFemaleMaleMaleMaleFemaleMaleMaleFe...
#
#                                                           Region  \
# CampaignGroup
# A              SouthWestSouthWestNorthWestWestEastEastNorthNo...
# B              SouthNorthSouthEastNorthEastEastSouthNorthSout...
#
#                PurchaseAmount  \
# CampaignGroup
# A                  2378072.13
# B                  2304880.04
#
#                                                  ProductCategory  \
# CampaignGroup
# A              FashionFashionGroceryFashionFashionElectronics...
# B              ElectronicsElectronicsFashionFashionFashionFas...
#
#                                                            Churn
# CampaignGroup
# A              NoNoNoYesYesNoNoNoYesNoNoYesNoYesYesNoYesNoNoN...
# ...

# %%
Purchase amount of A>B

# %% [markdown]
# Normal distribution using KDE plot

# %%
sns.kdeplot(df['PurchaseAmount'])
plt.show()

# %%
Central limit theorum

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df=pd.read_csv("/content/customer_behavior.csv")
print(round(df.sample(10)['PurchaseAmount'].mean(),2))
# Out:
# 983.22

# %% [markdown]
# The mean of 5001 values is 1003.95
# The mean of 10sample values is 983.22
# so CLT is True

# %% [markdown]
# 95% confidence intervel

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
df=pd.read_csv("/content/customer_behavior.csv")
df.head(5001)
# Out:
#       CustomerID  Gender Region  PurchaseAmount ProductCategory Churn  \
# 0           1001    Male  South          256.07         Fashion    No
# 1           1002  Female  South             NaN     Electronics   Yes
# 2           1003  Female   West         1194.41         Fashion    No
# 3           1004  Female  South          413.06         Grocery    No
# 4           1005    Male   West         1556.32         Fashion   Yes
# ...          ...     ...    ...             ...             ...   ...
# 4995        5996  Female   West         1497.00     Electronics   Yes
# 4996        5997    Male   West          978.87         Fashion   Yes
# 4997        5998    Male   West          906.93         Fashion    No
# 4998        5999  Female  South          375.67         Fashion    No
# 4999        6000  Female  North         1392.74         Grocery   Yes
#
#      CampaignGroup
# 0                A
# 1                B
# 2                A
# 3                A
# 4                A
# ...

# %%
P95=np.percentile(df['PurchaseAmount'],95)
print("95th percentile",P95)
# Out:
# 95th percentile nan
